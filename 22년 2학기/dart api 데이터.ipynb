# %% [markdown]
# https://coding-moomin.tistory.com/5

# %%
import requests 
import pandas as pd 
import io 
import zipfile
import xml.etree.ElementTree as et 
import json

# %%
crtfc_key = 'api키'

# %%
def get_corpcode(crtfc_key): 
    """ 
    OpenDART 기업 고유번호 받아오기 
    return 값: 주식코드를 가진 업체의 DataFrame 
    """ 
    params = {'crtfc_key':crtfc_key} 
    items = ["corp_code","corp_name","stock_code","modify_date"] 
    item_names = ["고유번호","회사명","종목코드","수정일"] 
    url = "https://opendart.fss.or.kr/api/corpCode.xml" #요청 url
    res = requests.get(url,params=params) #url 불러오기
    zfile = zipfile.ZipFile(io.BytesIO(res.content))  #zip file 받기
    fin = zfile.open(zfile.namelist()[0])  #zip file 열고
    root = et.fromstring(fin.read().decode('utf-8'))  #utf-8 디코딩
    data = [] 
    for child in root: 
        if len(child.find('stock_code').text.strip()) > 1: # 종목코드가 있는 경우 
            data.append([]) #data에 append하라 
            for item in items: 
                data[-1].append(child.find(item).text) 
    df = pd.DataFrame(data, columns=item_names) 
    return df

# %%
def Frame(url, items, item_names, params): 
    """
    url : json형태로 요청하는 주소
    items : 반환되는 데이터들의 key를 가진 리스트
    item_names :  데이터프레임을 만들때 컬럼명 리스트
    params : url 요청시 필수값으로 들어가는 인자들을 가진 딕셔너리
    """
    res = requests.get(url, params)
    json_data = res.json()
    json_dict = json.loads(res.text) 
    data = [] 
    if json_dict['status'] == "000":  # 오류 없이 정상적으로 데이터가 있다면 
        for line in json_dict['list']: 
            data.append([])
            for itm in items: 
                if itm in line.keys(): 
                    data[-1].append(line[itm]) 
                else: 
                    data[-1].append('')
    df = pd.DataFrame(data, columns=item_names)
    return df

# %%
def get_fnlttSinglAcntAll(crtfc_key, corp_code, bsns_year, reprt_code, fs_div = "CFS"): 
    items = ["rcept_no","reprt_code","bsns_year","corp_code","sj_div","sj_nm", 
             "account_id","account_nm","account_detail","thstrm_nm", "thstrm_amount",
             "thstrm_add_amount","frmtrm_nm","frmtrm_amount", "frmtrm_q_nm","frmtrm_q_amount",
             "frmtrm_add_amount","bfefrmtrm_nm", "bfefrmtrm_amount","ord"] 
    item_names = ["접수번호","보고서코드","사업연도","고유번호","재무제표구분", "재무제표명",
                  "계정ID","계정명","계정상세","당기명","당기금액", "당기누적금액","전기명","전기금액","전기명(분/반기)", 
                  "전기금액(분/반기)","전기누적금액","전전기명","전전기금액", "계정과목정렬순서"] 
    params = {'crtfc_key':crtfc_key, 'corp_code':corp_code, 'bsns_year':bsns_year, 'reprt_code':reprt_code, 'fs_div':fs_div} 
    url = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json?" 
    df = Frame(url, items, item_names, params)
    return df

# %%
stock_comp = get_corpcode(crtfc_key)
stock_comp[stock_comp['고유번호']=='00375302']
# Out:
#          고유번호     회사명    종목코드       수정일
# 313  00375302  우리금융지주  053000  20170630

# %%
company_list=pd.read_csv('업종별_시총_상위_10위_기업.csv',encoding='utf-8')

# %%
company_list.columns
# Out:
# Index(['회사명', '종목코드', '업종', '주요제품', '상장일', '결산월', '대표자명', '홈페이지', '지역', '시가총액',
#        '업종명', '대분류'],
#       dtype='object')

# %%
top_comp=stock_comp.loc[stock_comp['회사명'].isin(company_list['회사명']),:]

# %%
top_comp=top_comp.reset_index()
top_comp=top_comp.drop('index',axis=1)

# %%
#top_comp.to_csv("우리가_관심있는_기업들.csv",encoding='cp949')

# %%
corp_code = top_comp['고유번호']
final_reprt_df = get_fnlttSinglAcntAll(crtfc_key, corp_code[0], 2021, '11014', fs_div = "CFS") 
from tqdm import tqdm
for k in tqdm(range(1, len(corp_code))):
    reprt_df = get_fnlttSinglAcntAll(crtfc_key, corp_code[k], 2021, '11014', fs_div = "CFS") 
    final_reprt_df = pd.concat([final_reprt_df, reprt_df], axis = 0)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 102/102 [00:18<00:00,  5.47it/s]

# %%
import OpenDartReader

# %%
api_key = 'api_key'
dart = OpenDartReader(api_key)

# %%
df = dart.report(top_comp['고유번호'][5],'직원',2021)

# %%
df
# Out:
#          rcept_no corp_cls corp_code corp_name rm sexdstn fo_bbm  \
# 0  20220512000853        Y  00413046      셀트리온  -       남  관리사무직
# 1  20220512000853        Y  00413046      셀트리온  -       여  관리사무직
# 2  20220512000853        Y  00413046      셀트리온  -       남  연구개발직
# 3  20220512000853        Y  00413046      셀트리온  -       여  연구개발직
# 4  20220512000853        Y  00413046      셀트리온  -       남    생산직
# 5  20220512000853        Y  00413046      셀트리온  -       여    생산직
#
#   reform_bfe_emp_co_rgllbr reform_bfe_emp_co_cnttk reform_bfe_emp_co_etc  \
# 0                        -                       -                     -
# 1                        -                       -                     -
# 2                        -                       -                     -
# 3                        -                       -                     -
# 4                        -                       -                     -
# 5                        -                       -                     -
#
#   rgllbr_co rgllbr_abacpt_labrr_co cnttk_co cnttk_abacpt_labrr_co   sm  \
# 0       222                      -        5                     -  227
# 1       123                      -       12                    10  145
# 2       282                      -       17                     -  299
# 3       397                      -        5                     -  402
# 4       726                      -       34                     -  760
# 5       324                      -       50                     -  374
#
#   avrg_cnwk_sdytrn fyer_salary_totamt jan_salary_am
# 0              4.6     20,583,000,000    93,000,000
# 1              5.0      9,913,000,000    73,000,000
# 2              5.8     29,115,000,000    99,000,000
# 3              4.8     31,971,000,000    85,000,000
# 4              5.7     54,568,000,000    72,000,000
# 5              5.4     23,945,000,000    63,000,000

# %%
def tqreport(year):
    corp_code = top_comp['고유번호']
    final_reprt_df = dart.finstate(corp_code[0], year) 
    from tqdm import tqdm
    for k in tqdm(range(1, len(corp_code))):
        reprt_df = dart.finstate(corp_code[k], year) 
        final_reprt_df = pd.concat([final_reprt_df, reprt_df], axis = 0)
        
    final=final_reprt_df[final_reprt_df['sj_div']=='IS']
    final=final.astype({'corp_code':'str'})

    return final

# %%
data=tqreport(year=2021)
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#   1%|▊                                                                                 | 1/102 [00:00<00:15,  6.67it/s]
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#   2%|█▌                                                                                | 2/102 [00:00<00:14,  6.90it/s]
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#   8%|██████▍                                                                           | 8/102 [00:01<00:12,  7.27it/s]
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#  12%|█████████▌                                                                       | 12/102 [00:01<00:11,  7.66it/s]
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#  38%|██████████████████████████████▉                                                  | 39/102 [00:05<00:08,  7.37it/s]
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#  62%|██████████████████████████████████████████████████                               | 63/102 [00:08<00:10,  3.89it/s]
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#  75%|█████████████████████████████████████████████████████████████▏                   | 77/102 [00:11<00:03,  7.07it/s]
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#  88%|███████████████████████████████████████████████████████████████████████▍         | 90/102 [00:13<00:01,  7.56it/s]
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#  90%|█████████████████████████████████████████████████████████████████████████        | 92/102 [00:13<00:01,  7.22it/s]
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# 100%|████████████████████████████████████████████████████████████████████████████████| 102/102 [00:14<00:00,  6.95it/s]

# %%
data.to_csv("2021재무제표.csv",encoding='cp949')

# %%
data['account_nm'].unique()
# Out:
# array(['매출액', '영업이익', '법인세차감전 순이익', '당기순이익'], dtype=object)

# %%
print(data.shape)
print(data.columns)
# Out:
# (712, 21)
# Index(['rcept_no', 'reprt_code', 'bsns_year', 'corp_code', 'stock_code',
#        'fs_div', 'fs_nm', 'sj_div', 'sj_nm', 'account_nm', 'thstrm_nm',
#        'thstrm_dt', 'thstrm_amount', 'frmtrm_nm', 'frmtrm_dt', 'frmtrm_amount',
#        'bfefrmtrm_nm', 'bfefrmtrm_dt', 'bfefrmtrm_amount', 'ord', 'currency'],
#       dtype='object')

# %%
data['fs_nm'].unique
# Out:
# <bound method Series.unique of 9     연결재무제표
# 10    연결재무제표
# 11    연결재무제표
# 12    연결재무제표
# 22      재무제표
#        ...
# 10    연결재무제표
# 11    연결재무제표
# 21      재무제표
# 22      재무제표
# 23      재무제표
# Name: fs_nm, Length: 677, dtype: object>

# %%
top_comp
# Out:
#          고유번호     회사명    종목코드       수정일
# 0    00375302  우리금융지주  053000  20170630
# 1    00126229    삼성물산  000830  20170630
# 2    00144155      SK  003600  20170630
# 3    00126478   삼성중공업  010140  20211210
# 4    00121941      대상  001680  20211202
# ..        ...     ...     ...       ...
# 98   00162461   한화솔루션  009830  20220901
# 99   00136378     신세계  004170  20220908
# 100  00828497    한미약품  128940  20220407
# 101  00261285  한국가스공사  036460  20220407
# 102  00258801     카카오  035720  20221020
#
# [103 rows x 4 columns]

# %%
data
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 9   20220310001057      11011      2021  00126478     010140    CFS  연결재무제표
# 10  20220310001057      11011      2021  00126478     010140    CFS  연결재무제표
# 11  20220310001057      11011      2021  00126478     010140    CFS  연결재무제표
# 12  20220310001057      11011      2021  00126478     010140    CFS  연결재무제표
# 22  20220310001057      11011      2021  00126478     010140    OFS    재무제표
# ..             ...        ...       ...       ...        ...    ...     ...
# 10  20220321001331      11011      2021  00258801     035720    CFS  연결재무제표
# 11  20220321001331      11011      2021  00258801     035720    CFS  연결재무제표
# 21  20220321001331      11011      2021  00258801     035720    OFS    재무제표
# 22  20220321001331      11011      2021  00258801     035720    OFS    재무제표
# 23  20220321001331      11011      2021  00258801     035720    OFS    재무제표
#
#    sj_div  sj_nm  account_nm  ...                thstrm_dt  \
# 9      IS  손익계산서         매출액  ...  2021.01.01 ~ 2021.12.31
# 10     IS  손익계산서        영업이익  ...  2021.01.01 ~ 2021.12.31
# 11     IS  손익계산서  법인세차감전 순이익  ...  2021.01.01 ~ 2021.12.31
# 12     IS  손익계산서       당기순이익  ...  2021.01.01 ~ 2021.12.31
# 22     IS  손익계산서         매출액  ...  2021.01.01 ~ 2021.12.31
# ..    ...    ...         ...  ...                      ...
# 10     IS  손익계산서  법인세차감전 순이익  ...  2021.01.01 ~ 2021.12.31
# 11     IS  손익계산서       당기순이익  ...  2021.01.01 ~ 2021.12.31
# 21     IS  손익계산서        영업이익  ...  2021.01.01 ~ 2021.12.31
# 22     IS  손익계산서  법인세차감전 순이익  ...  2021.01.01 ~ 2021.12.31
# 23     IS  손익계산서       당기순이익  ...  2021.01.01 ~ 2021.12.31
#
#          thstrm_amount frmtrm_nm                frmtrm_dt       frmtrm_amount  \
# 9    6,622,001,487,326    제 47 기  2020.01.01 ~ 2020.12.31   6,860,317,642,496
# 10  -1,311,956,174,022    제 47 기  2020.01.01 ~ 2020.12.31  -1,054,144,023,100
# 11  -1,349,816,814,471    제 47 기  2020.01.01 ~ 2020.12.31  -1,475,030,182,281
# 12  -1,452,069,565,718    제 47 기  2020.01.01 ~ 2020.12.31  -1,492,699,901,584
# 22   6,542,631,445,460    제 47 기  2020.01.01 ~ 2020.12.31   6,825,532,312,130
# ..                 ...       ...                      ...                 ...
# 10   2,293,693,668,438    제 26 기  2020.01.01 ~ 2020.12.31     414,271,425,061
# 11   1,646,153,359,281    제 26 기  2020.01.01 ~ 2020.12.31     173,359,671,915
# 21     402,025,254,785    제 26 기  2020.01.01 ~ 2020.12.31     300,064,492,177
# 22     574,692,459,376    제 26 기  2020.01.01 ~ 2020.12.31     -35,091,884,829
# 23     506,621,417,832    제 26 기  2020.01.01 ~ 2020.12.31    -117,878,818,553
#
#    bfefrmtrm_nm             bfefrmtrm_dt    bfefrmtrm_amount ord currency
# 9        제 46 기  2019.01.01 ~ 2019.12.31   7,349,656,035,614  23      KRW
# 10       제 46 기  2019.01.01 ~ 2019.12.31    -616,585,523,278  25      KRW
# 11       제 46 기  2019.01.01 ~ 2019.12.31  -1,139,245,938,287  27      KRW
# 12       제 46 기  2019.01.01 ~ 2019.12.31  -1,315,353,147,184  29      KRW
# 22       제 46 기  2019.01.01 ~ 2019.12.31   7,098,805,561,786  24      KRW
# ..          ...                      ...                 ...  ..      ...
# 10       제 25 기  2019.01.01 ~ 2019.12.31    -234,256,905,702  27      KRW
# 11       제 25 기  2019.01.01 ~ 2019.12.31    -341,924,578,348  29      KRW
# 21       제 25 기  2019.01.01 ~ 2019.12.31     196,063,924,523  26      KRW
# 22       제 25 기  2019.01.01 ~ 2019.12.31    -230,629,069,957  28      KRW
# 23       제 25 기  2019.01.01 ~ 2019.12.31    -259,705,692,892  30      KRW
#
# [712 rows x 21 columns]

# %%
def report_worker(year):
    corp_code = top_comp['고유번호']
    final_reprt_df = dart.report(corp_code[0], '직원',year) 
    from tqdm import tqdm
    for k in tqdm(range(1, len(corp_code))):
        reprt_df = dart.report(corp_code[k],'직원', year) 
        final_reprt_df = pd.concat([final_reprt_df, reprt_df], axis = 0)
        

    return final_reprt_df

# %%
worker=report_worker(2021)
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#   1%|▊                                                                                 | 1/102 [00:00<00:13,  7.47it/s]
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#   2%|█▌                                                                                | 2/102 [00:00<00:14,  6.91it/s]
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# 100%|████████████████████████████████████████████████████████████████████████████████| 102/102 [00:16<00:00,  6.06it/s]

# %%
worker
# Out:
#           rcept_no corp_cls corp_code corp_name rm sexdstn fo_bbm  \
# 0   20220310001057        Y  00126478     삼성중공업  -       남     조선
# 1   20220310001057        Y  00126478     삼성중공업  -       여     조선
# 2   20220310001057        Y  00126478     삼성중공업  -       남     건설
# 3   20220310001057        Y  00126478     삼성중공업  -       여     건설
# 0   20220816001426        Y  00121941        대상  -       남     식품
# ..             ...      ...       ...       ... ..     ...    ...
# 3   20220325000211        Y  00261285    한국가스공사  -       여    기술직
# 4   20220325000211        Y  00261285    한국가스공사  -       남     기타
# 5   20220325000211        Y  00261285    한국가스공사  -       여     기타
# 0   20220321001331        Y  00258801       카카오  -       남     전사
# 1   20220321001331        Y  00258801       카카오  -       여     전사
#
#    reform_bfe_emp_co_rgllbr reform_bfe_emp_co_cnttk reform_bfe_emp_co_etc  \
# 0                         -                       -                     -
# 1                         -                       -                     -
# 2                         -                       -                     -
# 3                         -                       -                     -
# 0                         -                       -                     -
# ..                      ...                     ...                   ...
# 3                         -                       -                     -
# 4                         -                       -                     -
# 5                         -                       -                     -
# 0                         -                       -                     -
# 1                         -                       -                     -
#
#    rgllbr_co rgllbr_abacpt_labrr_co cnttk_co cnttk_abacpt_labrr_co     sm  \
# 0      8,585                      -       81                     -  8,666
# 1        324                     16       16                     -    340
# 2        232                      -       33                     -    265
# 3          5                      -        3                     -      8
# 0      1,737                      -       31                     1  1,768
# ..       ...                    ...      ...                   ...    ...
# 3        284                     10        -                     -    294
# 4        501                      2        -                     -    503
# 5         36                      1        -                     -     37
# 0      1,926                      -       32                     -  1,958
# 1      1,377                      -      137                     -  1,514
#
#    avrg_cnwk_sdytrn fyer_salary_totamt jan_salary_am
# 0             18.9     699,797,000,000    76,000,000
# 1             11.0      19,972,000,000    55,000,000
# 2             15.3       7,172,000,000    83,000,000
# 3              7.6         172,000,000    44,000,000
# 0           11년 1개월    124,891,000,000    66,000,000
# ..              ...                ...           ...
# 3              9.72     18,716,171,000    63,660,000
# 4             16.97     37,703,919,000    74,958,000
# 5             11.79      2,447,736,000    66,155,000
# 0           4년 10개월    381,472,000,000   217,000,000
# 1            5년 1개월    136,232,000,000   108,000,000
#
# [408 rows x 18 columns]

# %%
len(worker['corp_name'].unique())
# Out:
# 100
